# %% [markdown]
# # 🍀 Bienvenidos a Stable Diffusion 🍀<br>🐻 por [ositoMalvado](http://ositomalvado.free.nf/?i=1) 🐻<hr>
# - **Importante**:
# > Esta celda solo la ejecutas la primera vez que instales Stable Diffusion en tu SageMaker, o bien si haz restaurado todo el entorno.
# - **Advertencia**: no tocar el código.
# <hr>
# <footer>Todos los derechos reservados. ositoMalvado/Julián Perez</footer>

# %%
#🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫
#🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#                     NO TOCAR CÓDIGO ! ! !                     ☣️
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
import zipfile
import os
from IPython.utils.io import capture_output
from IPython.display import HTML, display, clear_output
def mostrar_en_div_estilizado(contenido):
    from IPython.display import HTML, display
    animation_style = """@keyframes moveBackground{0%{background-position:0 50%}100%{background-position:100% 50%}}"""
    div_style = """background:radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent),radial-gradient(circle at 50% 50%,rgba(0,255,0,.5),transparent),radial-gradient(circle at 80% 50%,rgba(0,0,255,.4),transparent),radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent);background-color:transparent;background-size:400% 400%;animation:moveBackground 60s linear infinite;color:#FFEFDF;padding:15px;border-radius:5px;font-weight:bold;font-family:monospace;box-shadow:0 4px 6px rgba(0,0,0,.5)"""
    display(HTML(f"<style>{animation_style}</style>"))
    div = f'<div class="alert alert-primary" style="{div_style}">{contenido}</div>'
    display(HTML(div))
mostrar_en_div_estilizado(f"<h1>😰 Instalando Programa Raíz!</h1><hr>🌎Proceso: 0% - Preparando entorno")
with capture_output() as c:
    # %cd /home/studio-lab-user
    # %env TF_CPP_MIN_LOG_LEVEL=3
    del c
clear_output()
mostrar_en_div_estilizado(f"<h1>😰 Instalando Programa Raíz!</h1><hr>🌏Proceso: 8% - Instalando y actualizando conda")
with capture_output() as c:
    # !conda install -c conda-forge libglib -y & conda update -n base conda -y
    del c
clear_output()
mostrar_en_div_estilizado(f"<h1>😢 Instalando Programa Raíz!</h1><hr>🌎Proceso: 29% - Instalando Stable Diffusion")
with capture_output() as c:
    # %conda install -q -y aria2
    # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
    # !curl -Lo "/home/studio-lab-user/stable-diffusion-webui/sd.zip" "https://huggingface.co/mordecaaiiaart/ositoMalvado/resolve/main/OSITO.zip"
    del c
clear_output()
mostrar_en_div_estilizado(f"<h1>😥 Instalando Programa Raíz!</h1><hr>🌏Proceso: 55% - Descargando configuraciones")
with capture_output() as c:
    with zipfile.ZipFile("/home/studio-lab-user/stable-diffusion-webui/sd.zip", 'r') as zip_ref:
        zip_ref.extractall(path="/home/studio-lab-user/stable-diffusion-webui")
    # !rm -rf /home/studio-lab-user/sd.zip
    del c
clear_output()
mostrar_en_div_estilizado(f"<h1>😦 Instalando Programa Raíz!</h1><hr>🌍Proceso: 76% - Creando directorios")
with capture_output() as c:
    # !mkdir /home/studio-lab-user/stable-diffusion-webui/outputs
    # !mkdir /home/studio-lab-user/stable-diffusion-webui/models/Lora
    # !mkdir /home/studio-lab-user/stable-diffusion-webui/models/ControlNet
    del c
clear_output()
mostrar_en_div_estilizado(f"<h1>🙂 Instalando Programa Raíz!</h1><hr>🌏Proceso: 93% - Descargando configuración final")
with capture_output() as c:
    # !curl -Lo "/home/studio-lab-user/stable-diffusion-webui/notification.mp3" "https://lithi.io/file/cxjL.mp3"
    # !curl -Lo "/home/studio-lab-user/stable-diffusion-webui/style.css" "https://lithi.io/file/euxO.rar"
    del c
clear_output()
mostrar_en_div_estilizado(f"<h1>😁 Instalación finalizada!</h1><hr>🌏Proceso: 100% - Sigue en la próxima celda!")

# %% [markdown]
# # 💫 Descarga de modelos y extensiones ✔️<hr>
# - **Cómo descargar los modelos?**
# > - Debes poner en **False** todo lo que no quieras! Solo pon **True** en lo que quieras, ten en cuenta las advertencias de los tamaños de los modelos.
# - **Importante**:
# > - Los modelos SDXL pesan ~6.5gb cada uno, por lo que se recomienda utilizar un solo modelo.
# > - Los modelos SD15 pesan de ~2gb a ~5gb cda uno, por lo que se recomienda utilizar dos modelos como mucho.
# > - Al utilizar los extras recomiendo utilizar un solo modelo de CHECKPOINT, debido a que los extras también ocupan bastante espacio en algunos casos.
# > - **Los modelos descargados permanecerán almacenados de manera permanente, si deseas cambiar y no te permite por el espacio, utiliza la celda correspondiente para eliminar los modelos**

# %%
##############
#    💫🐻🐴 Stable Diffusion - Descarga de modelos 🐴🐻💫
##############
sd_extensions = True
    # 🛠️ - Extensiones útiles para generación, puedes generar videos también.
sd_extensions_reactor = False
sd_extensions_deforum = False
sd_extensions_plus = False #controlnet + clip interrogator
extra_vae = False
    # 🎀 - False = 2 VAEs por defecto si está en false, solo para modelos SD1.5.
upscalers = False
    # ➕ - False = 4x-UltraSharp.

##############
#    Modelos SDXL 🤖
##############

    ##############
    #    Modelos SDXL 💫 - Extras
    ##############
sdxl_control = False
sdxl_control_qr = False
    # controlnet
sdxl_lora = False
sdxl_lora_text = False
    # modelos LORA para agregara más detalles
sdxl_embeddings = False
    # inversiones textuales para SDXL

    ##############
    #    Modelos SDXL 🌠 - Checkpoints
    ##############

sdxl_mini = False
    # https://huggingface.co/segmind/SSD-1B
sdxl_realisticDigitalGenius = False
    # https://civitai.com/models/133118/realistic-digital-genius-sdxl?modelVersionId=187992
sdxl_sdxxxl = False
    # https://civitai.com/models/167764/sdxxxl?modelVersionId=188681
sdxl_realitiesEdge = False
    # https://civitai.com/models/129666/realities-edge-xl?modelVersionId=183894
sdxl_thinkDiffusion = False
    # https://civitai.com/models/169868/thinkdiffusionxl?modelVersionId=190908
sdxl_starLight = False # casi SXZ LUMA
    # https://civitai.com/models/143043/starlight-xl-animated?modelVersionId=182077
sdxl_juggernautXL = False
    # https://civitai.com/models/133005/juggernaut-xl
sdxl_photostock = False
sdxl_bluepencil = False
    # https://huggingface.co/lllyasviel/fav_models/tree/main/fav
sdxl_devlish = False
    # https://civitai.com/models/156061/devlishphotorealism-sdxl
sdxl_yamerMix = False
    # https://civitai.com/models/84040/sdxl-unstable-diffusers-yamermix
sdxl_nightVision = False
    # https://civitai.com/models/128607/nightvision-xl-photorealistic-or-portrait-or-photography-or-hyperreal-or-architecture-or-interior-design-no-refiner-needed
sdxl_protoHighFidelity = False
    # https://civitai.com/models/125703/protovision-xl-high-fidelity-3d-photorealism-anime-hyperrealism-no-refiner-needed
sdxl_base_refiner = False
    # https://civitai.com/models/101055/sd-xl
sdxl_sdxlNijiSpecial = False
    # https://civitai.com/models/120765/sdxlnijispecial-edition
sdxl_xxmix9realisticsdxl = False
    # https://civitai.com/models/124421/xxmix9realisticsdxl
sdxl_dynavisionXLAllInOneStylized = False
    # https://civitai.com/models/122606/dynavision-xl-all-in-one-stylized-3d-sfw-and-nsfw-output-no-refiner-needed
sdxl_counterfeitxl = False
    # https://civitai.com/models/118406/counterfeitxl
sdxl_sdxlUnstableDiffusers_v7ElectricMind = False
    # https://civitai.com/models/84040/sdxl-unstable-diffusers-yamermix
sdxl_SDXLRonghua = False
    # https://civitai.com/models/125634/sdxl-ronghua-or-or
sdxl_copaxTimelessxlSDXL1 = False
    # https://civitai.com/models/118111/copax-timelessxl-sdxl10
sdxl_sdvn6Realxl_detailface = False
    # https://civitai.com/models/118114/sdvn6-realxl
sdxl_sdvn7Nijistylexl = False
    # https://civitai.com/models/123307/sdvn7-nijistylexl
sdxl_protovisionXLHighFidelity3D = False
    # https://civitai.com/models/125703/protovision-xl-high-fidelity-3d-photorealism-anime-hyperrealism-no-refiner-needed
sdxl_crystalClearXL_ccxl = False
    # https://civitai.com/models/122822/crystal-clear-xl
sdxl_LahMysteriousSDXL = False
    # https://civitai.com/models/118441/lah-mysterious-or-sdxl
sdxl_zavychromaxl = False
    # https://civitai.com/models/119229/zavychromaxl
sdxl_talmendoxlSDXL = False
    # https://civitai.com/models/119202/talmendoxl-sdxl-uncensored-full-model
sdxl_realvisxlV10 = False
    # https://civitai.com/models/139562/realvisxl-v10
sdxl_realisticStockPhoto = False
    # https://civitai.com/models/139565/realistic-stock-photo
sdxl_shikianimexl = False
    # https://civitai.com/models/119163/shikianimexl
sdxl_samaritan3dCartoon = False
    # https://civitai.com/models/81270/samaritan-3d-cartoon
sdxl_dreamshaperXL10 = False
    # https://civitai.com/models/112902/dreamshaper-xl10
sdxl_leosamsHelloworld = False
    # https://civitai.com/models/43977/leosams-helloworld-sdxl-model-historical-version-moonfilm-and-moonmix-sd15-model
sdxl_atlxl = False
    # https://civitai.com/models/120127/altxl
sdxl_wyvernmix = False
    # https://civitai.com/models/5273?modelVersionId=137252
sdxl_ffxl400GBXLCombined = False
    # https://civitai.com/models/143613/ffxl400gb-xl-combined-loras?modelVersionId=161462

##############
#    Modelos SD15 🤖
##############

    ##############
    #    Modelos SD15 💫 - Extras
    ##############
sd15_embeddings = False
    #Inversiones textuales
sd15_controlnet_v1 = False
    #Guía de control por referencia
sd15_controlnet_v2 = False

    ##############
    #    Modelos SD15 🌠 - Checkpoints
    ##############
    
    #⚡️**Fotorealistas**⚡️
objective_reality = False
chilloutmix = False
realistic_vision_v5_1 = False
deliberate = False
majicmix_realistic = False
epic_realism = False
epic_photogasm = False
cyber_realistic = False
xxmix_9_realistic = False
icbinp_i_cant_believe_its_not_photography = False
fantastic_mix = False
absolute_reality = False
am_i_real = False
photon = False
perfect_deliberate = False
cyber_realistic_classic = False
endless_reality = False

    #☄️**Arte digital / Ilustración**☄️
sxz_luma = False
dream_shaper = False
rev_animated = False
lyriel = False
babes = False
never_ending_dream_ned = False
liberty = False
elldreths_retro_mix = False
been_you_lite = False
ether_real_mix = False
dread_v5 = False
majicmix_fantasy = False
noosphere = False
model_ex = False
ghostmix = False
counterfeit_v3_0 = False
a_zovya_rpg_artist_tools = False
been_you = False
anything_v5_ink = False

    #💥**Arte digital / 2D / Anime**💥
cetus_mix = False
toonyou = False
dark_sushi_mix = False
anime = False
icomix = False
flat_2d_animerge = False
arthemy_comics = False
checkpoint_yesmix = False
the_agenda_mix = False
seekyou = False
experience = False

#🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫
#🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#                     NO TOCAR CÓDIGO ! ! !                     ☣️
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
import zipfile
import os
from IPython.display import clear_output
path_model = '/home/studio-lab-user/stable-diffusion-webui/models/Stable-diffusion/'
path_vae = '/home/studio-lab-user/stable-diffusion-webui/models/VAE/'
path_lora = '/home/studio-lab-user/stable-diffusion-webui/models/Lora/'
path_hypernetwork = '/home/studio-lab-user/stable-diffusion-webui/models/hypernetworks/'
path_upscaler = '/home/studio-lab-user/stable-diffusion-webui/models/ESRGAN/'
path_embedding = '/home/studio-lab-user/stable-diffusion-webui/embeddings/'
path_control = '/home/studio-lab-user/stable-diffusion-webui/models/ControlNet/'
path_extensiones = '/home/studio-lab-user/stable-diffusion-webui/extensions'
path_insight = '/home/studio-lab-user/stable-diffusion-webui/models/insightface'
path_adetailer = '/home/studio-lab-user/stable-diffusion-webui/models/adetailer'
def mostrar_en_div_estilizado(contenido):
    from IPython.display import HTML, display
    animation_style = """@keyframes moveBackground{0%{background-position:0 50%}100%{background-position:100% 50%}}"""
    div_style = """background:radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent),radial-gradient(circle at 50% 50%,rgba(0,255,0,.5),transparent),radial-gradient(circle at 80% 50%,rgba(0,0,255,.4),transparent),radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent);background-color:transparent;background-size:400% 400%;animation:moveBackground 60s linear infinite;color:#FFEFDF;padding:15px;border-radius:5px;font-weight:bold;font-family:monospace;box-shadow:0 4px 6px rgba(0,0,0,.5)"""
    display(HTML(f"<style>{animation_style}</style>"))
    div = f'<div class="alert alert-primary" style="{div_style}">{contenido}</div>'
    display(HTML(div))
def descargarModelo(url,id, total):
	destination = url.split(':')[0]
	nombre = url.split(':')[1]
	url = url[url.find(':')+1:]
	url = url[url.find(':')+1:]
	if 'model' in destination:
		destination = path_model
	elif 'vae' in destination:
		destination = path_vae
	elif 'lora' in destination:
		destination = path_lora
	elif 'hypernetwork' in destination:
		destination = path_hypernetwork
	elif 'embedd' in destination:
		destination = path_embedding
	elif 'control' in destination:
		destination = path_control
	elif 'upscaler' in destination:
		destination = path_upscaler
    elif 'insight' in destination:
        destination = path_insight
    elif 'adetailer' in destination:
        destination = path_adetailer
	if not os.path.exists(destination):
		os.makedirs(destination)
	mostrar_en_div_estilizado("<h1>😹 Descargando modelos Paso 2/3.</h1><h3>🔥Descargando modelo: " + nombre.split('.')[0] + " (" + str(id+1) + " de " + str(total+1) + ")" + "</h3>")
	if 'huggingface.co' in url:
		filename = url.split('/')[-1]
		# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M $url -d $destination -o $filename
	else:
		# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M $url -d $destination -o $nombre
	clear_output()
from IPython.utils.io import capture_output
def descargarModelos(modelos):
    for i, model in enumerate(modelos):    
        descargarModelo(model, i, len(modelos))
def descargarExtensiones(extensiones):
    for i, extension in enumerate(extensiones):
        url = extension.split('*')[0]
        nombre = url.split('/')[len(url.split('/'))-1]
        mostrar_en_div_estilizado("<h1>🥰 Descargando extensiones Paso 2/3.</h1><h3>🌟Descargando extensión (" + str(i+1) + " de " + str(len(extensiones)) + "): " + nombre + "</h3>")
        directorio = extension.split('*')[1] + '/' + nombre
        print(directorio)
        # !git clone --depth 1 $url $directorio
        if 'wildcard' in url:
            # !mkdir /home/studio-lab-user/stable-diffusion-webui/extensions/sd-dynamic-prompts/wildcards
            # !mv -f /home/studio-lab-user/stable-diffusion-webui/extensions/sd-dynamic-prompts/w/stableDiffusion-wildcards/wildcards/* /home/studio-lab-user/stable-diffusion-webui/extensions/sd-dynamic-prompts/wildcards
            # !rm -rf /home/studio-lab-user/stable-diffusion-webui/extensions/sd-dynamic-prompts/w
        clear_output()
modelos = []
extensiones = []
if sdxl_mini:
    modelos.append('model:sdxl_mini.safetensors:https://huggingface.co/segmind/SSD-1B/resolve/main/SSD-1B-A1111.safetensors')
if sdxl_realisticDigitalGenius:
    modelos.append('model:realisticDigital_v40.safetensors:https://civitai.com/api/download/models/187992')
if sdxl_sdxxxl:
    modelos.append('model:sdxxxl_v10.safetensors:https://civitai.com/api/download/models/188681')
if sdxl_realitiesEdge:
    modelos.append('model:RealitiesEdgeXL_5.safetensors:https://civitai.com/api/download/models/183894')
if sdxl_thinkDiffusion:
    modelos.append('model:thinkdiffusionxl_v10.safetensors:https://civitai.com/api/download/models/190908')
if sdxl_starLight:
    modelos.append('model:starlightXLAnimated_v3.safetensors:https://civitai.com/api/download/models/182077')
if sdxl_photostock:
    modelos.append('model:realisticStockPhoto_v10.safetensors:https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v10.safetensors')
if sdxl_bluepencil:
    modelos.append('model:bluePencilXL_v050.safetensors:https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/bluePencilXL_v050.safetensors')
if sdxl_devlish:
    modelos.append('model:devlishphotorealism_sdxl14.safetensors:https://civitai.com/api/download/models/185812')
if sdxl_yamerMix:
    modelos.append('model:sdxlUnstableDiffusers_v8HEAVENSWRATH.safetensors:https://civitai.com/api/download/models/174609')
if sdxl_nightVision:
    modelos.append('model:nightvisionXLPhotorealisticPortrait_release0770Bakedvae.safetensors:https://civitai.com/api/download/models/201643')
if sdxl_protoHighFidelity:
    modelos.append('model:protovisionXLHighFidelity3D_release0620Bakedvae.safetensors:https://civitai.com/api/download/models/172397')
if sdxl_base_refiner:
    modelos.append('model:sdXL_v10VAEFix.safetensors:https://civitai.com/api/download/models/128078')
    modelos.append('model:sdXL_v10RefinerVAEFix.safetensors:https://civitai.com/api/download/models/128080')
if sdxl_sdxlNijiSpecial:
    modelos.append('model:sdxl_sdxlNijiSpecial.safetensors:https://civitai.com/api/download/models/154625')
if sdxl_xxmix9realisticsdxl:
    modelos.append('model:sdxl_xxmix9realisticsdxl.safetensors:https://civitai.com/api/download/models/163192')
if sdxl_dynavisionXLAllInOneStylized:
    modelos.append('model:dynavisionXLAllInOneStylized_beta0411Bakedvae.safetensors:https://civitai.com/api/download/models/148259')
if sdxl_counterfeitxl:
    modelos.append('model:counterfeitxl_v10.safetensors:https://civitai.com/api/download/models/146761')
if sdxl_sdxlUnstableDiffusers_v7ElectricMind:
    modelos.append('model:sdxlUnstableDiffusers_v7ElectricMind.safetensors:https://civitai.com/api/download/models/164826')
if sdxl_SDXLRonghua:
    modelos.append('model:SDXLRonghua_v20.safetensors:https://civitai.com/api/download/models/151978')
if sdxl_juggernautXL:
    modelos.append('model:juggernautXL_version5.safetensors:https://civitai.com/api/download/models/198530')
    modelos.append('lora:JuggerCineXL2.safetensors:https://civitai.com/api/download/models/131991')
    modelos.append('embedding:JuggernautNegative-neg.pt:https://civitai.com/api/download/models/86553')
if sdxl_copaxTimelessxlSDXL1:
    modelos.append('model:copaxTimelessxlSDXL1_v6.safetensors:https://civitai.com/api/download/models/164378')
if sdxl_sdvn6Realxl_detailface:
    modelos.append('model:sdvn6Realxl_detailface.safetensors:https://civitai.com/api/download/models/134461')
if sdxl_sdvn7Nijistylexl:
    modelos.append('model:sdvn7Nijistylexl_v1.safetensors:https://civitai.com/api/download/models/155870')
if sdxl_protovisionXLHighFidelity3D:
    modelos.append('model:protovisionXLHighFidelity3D_beta0520Bakedvae.safetensors:https://civitai.com/api/download/models/144229')
if sdxl_crystalClearXL_ccxl:
    modelos.append('model:crystalClearXL_ccxl.safetensors:https://civitai.com/api/download/models/133832')
if sdxl_LahMysteriousSDXL:
    modelos.append('model:LahMysteriousSDXL_v40.safetensors:https://civitai.com/api/download/models/162380')
if sdxl_zavychromaxl:
    modelos.append('model:zavychromaxl_v20.safetensors:https://civitai.com/api/download/models/167488')
if sdxl_talmendoxlSDXL:
    modelos.append('model:talmendoxlSDXL_v11Beta.safetensors:https://civitai.com/api/download/models/131960')
if sdxl_realvisxlV10:
    modelos.append('model:realvisxlV10_v10VAE.safetensors:https://civitai.com/api/download/models/154590')
if sdxl_realisticStockPhoto:
    modelos.append('model:realisticStockPhoto_v10.safetensors:https://civitai.com/api/download/models/154593')
if sdxl_shikianimexl:
    modelos.append('model:shikianimexl_v10.safetensors:https://civitai.com/api/download/models/129369')
if sdxl_atlxl:
	modelos.append('model:altxl_v50.safetensors:https://civitai.com/api/download/models/144184')
if sdxl_wyvernmix:
	modelos.append('model:wyvernmix15XL_xlV11.safetensors:https://civitai.com/api/download/models/137252')
if sdxl_ffxl400GBXLCombined:
	modelos.append('model:ffxl400GBXLCombined_v20Pre.safetensors:https://civitai.com/api/download/models/142180')
if sdxl_dreamshaperXL10:
	modelos.append('model:sdxl_dreamshaperXL10.safetensors:https://civitai.com/api/download/models/126688')
if sdxl_leosamsHelloworld:
    modelos.append('modelo:sdxl_leosamsHelloworld.safetensors:https://civitai.com/api/download/models/150851')
if sdxl_samaritan3dCartoon:
    modelos.append('model:sdxl_samaritan3dCartoon.safetensors:https://civitai.com/api/download/models/144566')
if objective_reality:
    modelos.append('model:objective_reality.safetensors:https://civitai.com/api/download/models/142465')
if chilloutmix:
    modelos.append('model:chilloutmix.safetensors:https://civitai.com/api/download/models/11745')
if realistic_vision_v5_1:
    modelos.append('model:realistic_vision_v5_1.safetensors:https://civitai.com/api/download/models/130072')
if deliberate:
    modelos.append('model:deliberate.safetensors:https://civitai.com/api/download/models/15236')
if majicmix_realistic:
    modelos.append('model:majicmix_realistic.safetensors:https://civitai.com/api/download/models/126470')
if epic_realism:
    modelos.append('model:epic_realism.safetensors:https://civitai.com/api/download/models/134065')
if epic_photogasm:
    modelos.append('model:epic_photogasm.safetensors:https://civitai.com/api/download/models/145885')
if cyber_realistic:
    modelos.append('model:cyber_realistic.safetensors:https://civitai.com/api/download/models/138176')
if xxmix_9_realistic:
    modelos.append('model:xxmix_9_realistic.safetensors:https://civitai.com/api/download/models/102222')
if icbinp_i_cant_believe_its_not_photography:
    modelos.append('model:icbinp_i_cant_believe_its_not_photography.safetensors:https://civitai.com/api/download/models/121557')
if fantastic_mix:
    modelos.append('model:fantastic_mix.safetensors:https://civitai.com/api/download/models/129240')
if absolute_reality:
    modelos.append('model:absolute_reality.safetensors:https://civitai.com/api/download/models/132760')
if am_i_real:
    modelos.append('model:am_i_real.safetensors:https://civitai.com/api/download/models/115526')
if experience:
    modelos.append('model:experience.safetensors:https://civitai.com/api/download/models/137204')
if photon:
    modelos.append('model:photon.safetensors:https://civitai.com/api/download/models/90072')
if perfect_deliberate:
    modelos.append('model:perfect_deliberate.safetensors:https://civitai.com/api/download/models/86698')
if cyber_realistic_classic:
    modelos.append('model:cyber_realistic_classic.safetensors:https://civitai.com/api/download/models/129379')
if endless_reality:
    modelos.append('model:endless_reality.safetensors:https://civitai.com/api/download/models/111513')
if sxz_luma:
    modelos.append('model:sxz_luma.safetensors:https://civitai.com/api/download/models/127416')
if dream_shaper:
    modelos.append('model:dream_shaper.safetensors:https://civitai.com/api/download/models/128713')
if rev_animated:
    modelos.append('model:rev_animated.safetensors:https://civitai.com/api/download/models/46846')
if lyriel:
    modelos.append('model:lyriel.safetensors:https://civitai.com/api/download/models/72396')
if babes:
    modelos.append('model:babes.safetensors:https://civitai.com/api/download/models/61372')
if never_ending_dream_ned:
    modelos.append('model:never_ending_dream_ned.safetensors:https://civitai.com/api/download/models/64094')
if liberty:
    modelos.append('model:liberty.safetensors:https://civitai.com/api/download/models/6908')
if elldreths_retro_mix:
    modelos.append('model:elldreths_retro_mix.safetensors:https://civitai.com/api/download/models/1575')
if been_you_lite:
    modelos.append('model:been_you_lite.safetensors:https://civitai.com/api/download/models/117019')
if ether_real_mix:
    modelos.append('model:ether_real_mix.safetensors:https://civitai.com/api/download/models/124104')
if dread_v5:
    modelos.append('model:dread_v5.safetensors:https://civitai.com/api/download/models/104018')
if majicmix_fantasy:
    modelos.append('model:majicmix_fantasy.safetensors:https://civitai.com/api/download/models/49055')
if noosphere:
    modelos.append('model:noosphere.safetensors:https://civitai.com/api/download/models/107675')
if model_ex:
    modelos.append('model:model_ex.safetensors:https://civitai.com/api/download/models/137783')
if ghostmix:
    modelos.append('model:ghostmix.safetensors:https://civitai.com/api/download/models/76907')
if counterfeit_v3_0:
    modelos.append('model:counterfeit_v3_0.safetensors:https://civitai.com/api/download/models/57618')
if a_zovya_rpg_artist_tools:
    modelos.append('model:a_zovya_rpg_artist_tools.safetensors:https://civitai.com/api/download/models/87886')
if been_you:
    modelos.append('model:been_you.safetensors:https://civitai.com/api/download/models/85614')
if anything_v5_ink:
    modelos.append('model:anything_v5_ink.safetensors:https://civitai.com/api/download/models/90854')
if cetus_mix:
    modelos.append('model:cetus_mix.safetensors:https://civitai.com/api/download/models/105924')
if toonyou:
    modelos.append('model:toonyou.safetensors:https://civitai.com/api/download/models/125771')
if dark_sushi_mix:
    modelos.append('model:dark_sushi_mix.safetensors:https://civitai.com/api/download/models/93208')
if anime:
    modelos.append('model:anime.safetensors:https://civitai.com/api/download/models/116978')
if icomix:
    modelos.append('model:icomix.safetensors:https://civitai.com/api/download/models/84783')
if flat_2d_animerge:
    modelos.append('model:flat_2d_animerge.safetensors:https://civitai.com/api/download/models/103436')
if arthemy_comics:
    modelos.append('model:arthemy_comics.safetensors:https://civitai.com/api/download/models/107847')
if checkpoint_yesmix:
    modelos.append('model:checkpoint_yesmix.safetensors:https://civitai.com/api/download/models/95214')
if the_agenda_mix:
    modelos.append('model:the_agenda_mix.safetensors:https://civitai.com/api/download/models/95687')
if seekyou:
    modelos.append('model:seekyou.safetensors:https://civitai.com/api/download/models/74057')
modelos.append('upscaler:4xUltrasharp.pt:https://civitai.com/api/download/models/125843')
modelos.append('adetailer:breasts_seg.pt:https://huggingface.co/mordecaaiiaart/ositoMalvado/resolve/main/breasts_seg.pt')
modelos.append('adetailer:Eyes.pt:https://huggingface.co/mordecaaiiaart/ositoMalvado/resolve/main/Eyes.pt')
if upscalers:
    modelos.append('upscaler:4x-AnimeSharp.pth:https://huggingface.co/mordecaaiiaart/osmal/resolve/main/4x-AnimeSharp.pth')
    modelos.append('upscaler:4xSmoothRealism.pth:https://huggingface.co/mordecaaiiaart/osmal/resolve/main/|')
    modelos.append('upscaler:4x_NMKD-Superscale-SP_178000_G.pth:https://huggingface.co/mordecaaiiaart/osmal/resolve/main/4x_NMKD-Superscale-SP_178000_G.pth')
    modelos.append('upscaler:4x_Nickelback_70000G.pth:https://huggingface.co/mordecaaiiaart/osmal/resolve/main/4x_Nickelback_70000G.pth')
    modelos.append('upscaler:4x_UltraFArt_v3.pth:https://huggingface.co/mordecaaiiaart/osmal/resolve/main/4x_UltraFArt_v3.pth')
    modelos.append('upscaler:4x_foolhardy_Remacri.pth:https://huggingface.co/mordecaaiiaart/osmal/resolve/main/4x_foolhardy_Remacri.pth')
if extra_vae:
    modelos.append('vae:blessed2.vae.safetensors:https://huggingface.co/NoCrypt/resources/resolve/main/VAE/blessed2.vae.safetensors')
    modelos.append('vae:vae-ft-mse-840000-ema-pruned.safetensors:https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors')
    modelos.append('vae:https://civitai.com/api/download/models/94036')
    modelos.append('vae:https://civitai.com/api/download/models/83798')
    modelos.append('vae:https://civitai.com/api/download/models/83141')
else:
    modelos.append('vae:blessed2.vae.safetensors:https://huggingface.co/NoCrypt/resources/resolve/main/VAE/blessed2.vae.safetensors')
    modelos.append('vae:vae-ft-mse-840000-ema-pruned.safetensors:https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors')
if sd15_embeddings:
    extensiones.append('https://github.com/dreamscapeai/negativekit*' + path_embedding)
if sdxl_embeddings:
    extensiones.append('https://github.com/ositoMalvado/sdxl_embeddings*/home/studio-lab-user/stable-diffusion-webui/embeddings')
if sdxl_lora_text:
    modelos.append('lora:Harrlogos_v2.0.safetensors:https://civitai.com/api/download/models/214296')
if sdxl_lora:
    modelos.append('lora:DetailedEyes_V3.safetensors:https://civitai.com/api/download/models/145907')
    modelos.append('lora:xl_more_art-full_v1.safetensors:https://civitai.com/api/download/models/152309')
    modelos.append('lora:add-detail-xl.safetensors:https://civitai.com/api/download/models/135867')
    modelos.append('lora:EasyFix.safetensors:https://civitai.com/api/download/models/166739')
    modelos.append('lora:SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors:https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors')
    modelos.append('lora:badhands.safetensors:https://civitai.com/api/download/models/141278')
if sd15_controlnet_v1:
    modelos.append('control:tile_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors')
    modelos.append('control:tile_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.yaml')
    modelos.append('control:depth_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors')
    modelos.append('control:depth_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.yaml')
    modelos.append('control:qrcode_monster_v2.yaml:https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/v2/control_v1p_sd15_qrcode_monster_v2.yaml')
    modelos.append('control:qrcode_monster_v2.safetensors:https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/v2/control_v1p_sd15_qrcode_monster_v2.safetensors')
    modelos.append('control:canny_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors')
    modelos.append('control:canny_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.yaml')
    modelos.append('control:lineart_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors')
    modelos.append('control:lineart_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.yaml')
    modelos.append('control:openpose_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors')
    modelos.append('control:openpose_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.yaml')
    modelos.append('control:scribble_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors')
    modelos.append('control:scribble_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.yaml')
if sd15_controlnet_v2:
    modelos.append('control:ip2p_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors')
    modelos.append('control:ip2p_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.yaml')
    modelos.append('control:shuffle_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors')
    modelos.append('control:shuffle_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.yaml')
    modelos.append('control:depth_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_depth_fp16.safetensors')
    modelos.append('control:depth_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_depth_fp16.yaml')
    modelos.append('control:inpaint_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors')
    modelos.append('control:inpaint_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.yaml')
    modelos.append('control:mlsd_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors')
    modelos.append('control:mlsd_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.yaml')
    modelos.append('control:normalbae_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors')
    modelos.append('control:normalbae_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.yaml')
    modelos.append('control:seg_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors')
    modelos.append('control:seg_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.yaml')
    modelos.append('control:softedge_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors')
    modelos.append('control:softedge_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.yaml')
    modelos.append('control:lineart_anime_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors')
    modelos.append('control:lineart_anime_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.yaml')
if sdxl_control:
    modelos.append('control:sai_xl_canny_256lora.safetensors:https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_canny_256lora.safetensors')
    modelos.append('control:sai_xl_depth_256lora.safetensors:https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_depth_256lora.safetensors')
    modelos.append('control:adapter_xl_openpose.safetensors:https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_xl_openpose.safetensors')
    modelos.append('control:kohya_controllllite_xl_blur.safetensors:https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/kohya_controllllite_xl_blur.safetensors')
if sdxl_control_qr:
    modelos.append('control:control_v01u_sdxl_qrpattern.safetensors:https://huggingface.co/Nacholmo/controlnet-qr-pattern-sdxl/resolve/main/automatic1111/control_v01u_sdxl_qrpattern.safetensors')
if sd_extensions:
    extensiones.append('https://github.com/zanllp/sd-webui-infinite-image-browsing*' + path_extensiones)
    extensiones.append('https://github.com/Bing-su/adetailer*' + path_extensiones)
    extensiones.append('https://github.com/Coyote-A/ultimate-upscale-for-automatic1111*' + path_extensiones)
    extensiones.append('https://github.com/DominikDoom/a1111-sd-webui-tagcomplete*' + path_extensiones)
    extensiones.append('https://github.com/thomasasfk/sd-webui-aspect-ratio-helper*' + path_extensiones)
    extensiones.append('https://github.com/uwidev/sd_extension-prompt_formatter*' + path_extensiones)
    extensiones.append('https://github.com/adieyal/sd-dynamic-prompts*' + path_extensiones)
    extensiones.append('https://github.com/ositoMalvado/stableDiffusion-wildcards*' + path_extensiones + '/sd-dynamic-prompts/w')
    extensiones.append('https://github.com/ArtVentureX/sd-webui-agent-scheduler*' + path_extensiones)
    extensiones.append('https://github.com/pkuliyi2015/multidiffusion-upscaler-for-automatic1111*' + path_extensiones)
    if sd_extensions_reactor:
        extensiones.append('https://github.com/Gourieff/sd-webui-reactor*' + path_extensiones)
        modelos.append('insight:inswapper_128.onnx:https://huggingface.co/ezioruan/inswapper_128.onnx/resolve/main/inswapper_128.onnx')
    if sd_extensions_deforum:
        extensiones.append('https://github.com/deforum-art/sd-webui-deforum*' + path_extensiones)
    if sd_extensions_plus:
        extensiones.append('https://github.com/Mikubill/sd-webui-controlnet*' + path_extensiones)
        extensiones.append('https://github.com/pharmapsychotic/clip-interrogator-ext*' + path_extensiones)
descargarModelos(modelos)
descargarExtensiones(extensiones)
clear_output()
if sd_extensions:
    mostrar_en_div_estilizado("<h1>🥰 Descargando extra Paso 2/3.</h1><h3>🌟Descargando modelos wildcards</h3>")
    with capture_output() as c:
        # %cd /home/studio-lab-user/stable-diffusion-webui/extensions
        # !aria2c "https://huggingface.co/mordecaaiiaart/ositoMalvado/resolve/main/wildcardsForDynamic_v10.zip" -o "/sd-dynamic-prompts/wildcards/wc.zip"
        with zipfile.ZipFile("/home/studio-lab-user/stable-diffusion-webui/extensions/sd-dynamic-prompts/wildcards/wc.zip", 'r') as zip_ref:
            zip_ref.extractall(path="/home/studio-lab-user/stable-diffusion-webui/extensions/sd-dynamic-prompts/wildcards")
        # !rm -rf /home/studio-lab-user/stable-diffusion-webui/extensions/sd-dynamic-prompts/wildcards/wc.zip
    del c
clear_output()
mostrar_en_div_estilizado(f"<h1>👽 Modelos y extensiones descargados! Ya puedes iniciar Stable Diffusion en la siguiente celda!</h1>")

# %% [markdown]
# # 🚀 Iniciar Stable Diffusion 🛸<hr>
# - **Importante**:
# > [Debes usar tu propio token de ngrok](https://dashboard.ngrok.com/get-started/your-authtoken). Iniciando la sesión en esta página podrás obtener tu token. Colócalo en la celda de abajo. IMPORTANTE: NO MODIFICAR CÓDIGO
# >
# - **Ejemplo**:
# > ```
# > ngrok_token = "TU_TOKEN_AQUÍ"
# > ```

# %%
ngrok_token = "TU_TOKEN_AQUÍ"

#🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫
#🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#                     NO TOCAR CÓDIGO ! ! !                     ☣️
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
#INICIAR STABLE DIFFUSION CON ESTA CELDA
import os
from IPython.display import HTML, display, clear_output
from IPython.utils.io import capture_output
def mostrar_en_div_estilizado(contenido):
    animation_style = """@keyframes moveBackground{0%{background-position:0 50%}100%{background-position:100% 50%}}"""
    div_style = """background:radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent),radial-gradient(circle at 50% 50%,rgba(0,255,0,.5),transparent),radial-gradient(circle at 80% 50%,rgba(0,0,255,.4),transparent),radial-gradient(circle at 20% 50%,rgba(255,0,0,.4),transparent);background-color:transparent;background-size:400% 400%;animation:moveBackground 60s linear infinite;color:#FFEFDF;padding:15px;border-radius:5px;font-weight:bold;font-family:monospace;box-shadow:0 4px 6px rgba(0,0,0,.5)"""
    display(HTML(f"<style>{animation_style}</style>"))
    div = f'<div class="alert alert-primary" style="{div_style}">{contenido}</div>'
    display(HTML(div))
div_style = """
    text-align: center;
    margin: 0 auto;
"""
img_style = """
    padding: 2px;
    border-radius: 5px;
"""
mostrar_en_div_estilizado(f'<h1>Optimizando entorno!</h1><h6>Paso final 🐻</h6>')
with capture_output() as c:
    # %cd /home/studio-lab-user/
    # !git clone -b colab https://github.com/camenduru/gperftools
    # %cd /home/studio-lab-user/gperftools
    # %env CXXFLAGS=-std=c++14
    # !chmod +x /home/studio-lab-user/gperftools/configure
    # !./configure --enable-minimal --enable-libunwind --enable-frame-pointers --enable-dynamic-sized-delete-support --enable-sized-delete --enable-emergency-malloc; make -j4
    # !cp .libs/libtcmalloc*.so* /home/studio-lab-user/
    # %env LD_PRELOAD=/home/studio-lab-user/libtcmalloc_minimal.so.4
    del c
clear_output()
mostrar_en_div_estilizado(f'<h1>Abriendo Stable Diffusion!</h1><h6>Creado por ositoMalvado 🐻</h6>Paso 3/3.<hr><h4>Ahora espera a ver el código como en la imágen de abajo</h4><div style="{div_style}"><img src="https://lithi.io/file/6f0l.png" style="{img_style}"/><h4>Haz click en el link que termina en <strong>.ngrok-free.app</strong></hr><img src="https://i.imgur.com/kndOD01.png" style="{img_style}"/><h4>Finalmente haz click en "Visit Site" para abrir Stable Diffusion!</h4>')
file_path = "/home/studio-lab-user/stable-diffusion-webui/webui-user.bat"
line_to_add = 'set PYTORCH_CUDA_ALLOC_CONF=garbage_collection_threshold:0.9,max_split_size_mb:512'
if os.path.isfile(file_path):
    with open(file_path, 'r+') as file:
        content = file.read()
        if line_to_add not in content:
            file.seek(0, 0)
            file.write(line_to_add + '\n' + content)
# %cd /home/studio-lab-user/stable-diffusion-webui
# !python launch.py --opt-split-attention-v1 --opt-split-attention --xformers --upcast-sampling --listen --enable-insecure-extension-access --no-half-vae --theme dark --gradio-queue --ngrok $ngrok_token

# %% [markdown]
# # 📷 Guardar Todas Las Imágenes 💾
# - Importante:
# > No es necesario que estes corriendo el Stable Diffusion para guardar las imágenes. Estas se encuentran en la carpeta de Stable Diffusion > Outputs, recomiendo eliminar de vez en cuando para evitar que se llene el espacio. Descarga el archivo "imagenes.zip" generado en la raíz del directorio de archivos (con clic derecho "Download" podrás descargar el ZIP con tus imágenes generadas). IMPORTANTE: NO MODIFICAR CÓDIGO

# %%
#🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫
#🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#                     NO TOCAR CÓDIGO ! ! !                     ☣️
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
import zipfile
import os
from IPython.display import HTML, display, clear_output
def mostrar_en_div_estilizado(contenido):
    div_style = """
        background-color: #007BFF;
        color: #FFFFFF;
        padding: 15px;
        border-radius: 5px;
        font-weight: bold;
        font-family: Arial, sans-serif;
    """
    div = f'<div class="alert alert-primary" style="{div_style}">{contenido}</div>'
    display(HTML(div))
def comprimir_directorio_en_zip(directorio, archivo_zip):
    with zipfile.ZipFile(archivo_zip, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for carpeta_actual, subcarpetas, archivos in os.walk(directorio):
            for archivo in archivos:
                ruta_completa = os.path.join(carpeta_actual, archivo)
                ruta_relativa = os.path.relpath(ruta_completa, directorio)
                zipf.write(ruta_completa, ruta_relativa)
mostrar_en_div_estilizado(f'Guardando imágenes en ZIP: "/home/studio-lab-user/imagenes.zip"')
comprimir_directorio_en_zip('/home/studio-lab-user/stable-diffusion-webui/outputs', '/home/studio-lab-user/imagenes.zip')
clear_output()
mostrar_en_div_estilizado(f'Se guardaron las imágenes en "/home/studio-lab-user/imagenes.zip"')

# %% [markdown]
# # 🧨 Borrar Modelos ❌
# - **Importante**:
# > Pon "**#**" a lo que quieras mantener, quitale "**#**" para eliminar.

# %%
directorios = [] #No tocar esta línea

#   -> Para eliminar los modelos que deseas quítale el '#' a la línea que desees

#    CHECKPOINT
#directorios.append('/home/studio-lab-user/stable-diffusion-webui/models/Stable-diffusion/')
#    VAE
#directorios.append('/home/studio-lab-user/stable-diffusion-webui/models/VAE/')
#    LORA
#directorios.append('/home/studio-lab-user/stable-diffusion-webui/models/Lora/')
#    HYPERNETWORKS
#directorios.append('/home/studio-lab-user/stable-diffusion-webui/models/hypernetworks/')
#    UPSCALERS
#directorios.append('/home/studio-lab-user/stable-diffusion-webui/models/ESRGAN/')
#    EMBEDDINGS
#directorios.append('/home/studio-lab-user/stable-diffusion-webui/embeddings/')
#    CONTROLNET
#directorios.append('/home/studio-lab-user/stable-diffusion-webui/models/ControlNet/')
#    EXTENSIONES
#directorios.append('/home/studio-lab-user/stable-diffusion-webui/extensions')

#🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫
#🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#                     NO TOCAR CÓDIGO ! ! !                     ☣️
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
from IPython.display import HTML, display, clear_output
def mostrar_en_div_estilizado(contenido):
    div_style = """
        background-color: #007BFF;
        color: #FFFFFF;
        padding: 15px;
        border-radius: 5px;
        font-weight: bold;
        font-family: Arial, sans-serif;
    """
    div = f'<div class="alert alert-primary" style="{div_style}">{contenido}</div>'
    display(HTML(div))
for directorio in directorios:
    # !rm -rf $directorio
clear_output()
mostrar_en_div_estilizado("<h1>🦋 Modelos eliminados! 🌼</h1>")

# %% [markdown]
# # 🔨 Restaurar desde 0 ✔️
# - **Importante**:
# > Esta celda sirve para dejar SageMaker + Jupyter (todo tu entorno) desde 0, por lo que al ejecutar tendrás que apagar el Entorno desde SageMaker y luego abrirlo nuevamente con GPU para empezar desde 0 nuevamente.

# %%
#🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫🚫
#🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#                     NO TOCAR CÓDIGO ! ! !                     ☣️
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
import subprocess
output = subprocess.check_output(["conda", "env", "list"]).decode("utf-8")
lines = output.strip().split('\n')
for line in lines:
    parts = line.split()
    if len(parts) >= 2:
        env_name = parts[0]
        env_path = parts[1]
        if env_name != "base":
            subprocess.run(["conda", "activate", "base"])
            subprocess.run(["conda", "env", "remove", "--name", env_name])
            print(f"Entorno Conda '{env_name}' eliminado.")
print(f"REINICIA EL ENTORNO DE SAGEMAKER POR COMPLETO!")
