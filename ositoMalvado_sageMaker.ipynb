# %% [markdown]
# # 🍀 Bienvenidos a Stable Diffusion 🐻
# Celda 1 de 3
# - Importante:
# > Este paso es necesario que lo ejecutes una sola vez. Aunque si tienes problemas por haber modificado algo luego de ya tenerlo instladao, o no pudiste iniciar/instalar bien el Stable Diffusion, entonces elimina todos los archivos del directorio de tu Entorno Virtual de SageMaker, y luego corre esta celda.

# %%
import zipfile
import os
from IPython.utils.io import capture_output
from IPython.display import HTML, display, clear_output
def mostrar_en_div_estilizado(contenido):
    div_style = """
        background-color: #007BFF;
        color: #FFFFFF;
        padding: 15px;
        border-radius: 5px;
        font-weight: bold;
        font-family: Arial, sans-serif;
    """
    div = f'<div class="alert alert-primary" style="{div_style}">{contenido}</div>'
    display(HTML(div))
mostrar_en_div_estilizado(f"Instalando Programa Raíz!")
with capture_output() as c:
    # %cd /home/studio-lab-user
    # %env TF_CPP_MIN_LOG_LEVEL=1
    # !conda install -c conda-forge libglib -y & conda update -n base conda -y
    # !mkdir /home/studio-lab-user/stable-diffusion-webui/
    # !curl -Lo "/home/studio-lab-user/sd.zip" "https://lithi.io/file/VTRl.zip"
    with zipfile.ZipFile("/home/studio-lab-user/sd.zip", 'r') as zip_ref:
        zip_ref.extractall(path="/home/studio-lab-user/stable-diffusion-webui")
    # !mkdir /home/studio-lab-user/stable-diffusion-webui/outputs
    # !mkdir /home/studio-lab-user/stable-diffusion-webui/models/Lora
    # !mkdir /home/studio-lab-user/stable-diffusion-webui/models/ControlNet
    # !curl -Lo "/home/studio-lab-user/stable-diffusion-webui/notification.mp3" "https://lithi.io/file/cxjL.mp3"
    # !curl -Lo "/home/studio-lab-user/stable-diffusion-webui/style.css" "https://lithi.io/file/euxO.rar"
    del c
clear_output()
mostrar_en_div_estilizado(f"Ya podes descargar los modelos de Stable Diffusion en la siguiente celda!")

# %% [markdown]
# # 💫 Descarga de modelos y extensiones
# Celda 2 de 3
#
# - Importante:
# - - Los modelos SDXL pesan ~6.5gb cada uno, por lo que se recomienda utilizar un solo modelo, o dos como mucho.
# - - Los modelos SD15 pesan de ~2gb a ~5gb cda uno, por lo que se recomienda utilizar dos, o tres modelos como mucho.
# - - Al utilizar los extras recomiendo utilizar un solo modelo de CHECKPOINT, debido a que los extras también ocupan bastante espacio en algunos casos.
# - - **Los modelos descargados permanecerán almacenados de manera permanente, si deseas cambiar y no te permite por el espacio, busca la ruta de los modelos y los eliminas manualmente, más adelante haré una celda para que sea más fácil**
# - Cómo usar?
# - - Debes poner en False todo lo que no quieras! Solo pon True en lo que quieras, ten en cuenta las advertencias de los tamaños de los modelos.

# %%
#EXTENSIONES
sd_extensions = True # Extensiones útiles para generación, puedes generar videos también.
extra_vae = False # 2 VAEs por defecto si está en false, solo para ADETAILER o modelos 1.5.

                                    # MODELOS SDXL INICIO
    #EXTRA SDXL
sdxl_control = False #controlnet
sdxl_lora = False #modelos LORA para agregara más detalles
sdxl_embeddings = False #inversiones textuales para SDXL
    #CHECKPOINTS SDXL - Estos pesan ~6.5gb cada uno.
sdxl_crystalclear_realista = False
sdxl_atlxl = False
sdxl_wyvernmix = False
sdxl_realxl = False
sdxl_juggernaut_realista = False
sdxl_perfectdesign_sxzluma = False
sdxl_bluepencil_anime = False
sdxl_shikianime_anime = False
sdxl_realcartoon = False
sdxl_ambience = False
sdxl_zavy_chroma = False
sdxl_faestatic = False
sdxl_mysterious_ilustracion = False
sdxl_realart_artedigital = False
sdxl_yamer_anime = False
sdxl_duchaiten_ilustracion = False
sdxl_protovision_alicia = False
sdxl_dreamshaper = False
sdxl_dynavision_arteDigital = False
sdxl_yamer_ilustracion = False
sdxl_copax_realista = False

                                    # MODELOS SD15
    #EXTRA SD1.5
sd15_embeddings = False #Inversiones textuales
sd15_controlnet_v1 = False #Guía de control por referencia
sd15_controlnet_v2 = False #Guía de control por referencia
    #CHECKPOINTS SD1.5 - Pesan de ~2gb a ~5gb cada uno.
        #⚡️**Fotorealistas**⚡️
objective_reality = False
chilloutmix = False
realistic_vision_v5_1 = False
deliberate = False
majicmix_realistic = False
epic_realism = False
epic_photogasm = False
cyber_realistic = False
xxmix_9_realistic = False
icbinp_i_cant_believe_its_not_photography = False
fantastic_mix = False
absolute_reality = False
am_i_real = False
photon = False
perfect_deliberate = False
cyber_realistic_classic = False
endless_reality = False
    #☄️**Arte digital / Ilustración**☄️
sxz_luma = False
dream_shaper = False
rev_animated = False
lyriel = False
babes = False
never_ending_dream_ned = False
liberty = False
elldreths_retro_mix = False
been_you_lite = False
ether_real_mix = False
dread_v5 = False
majicmix_fantasy = False
noosphere = False
model_ex = False
ghostmix = False
counterfeit_v3_0 = False
a_zovya_rpg_artist_tools = False
been_you = False
anything_v5_ink = False
    #💥**Arte digital / 2D / Anime**💥
cetus_mix = False
toonyou = False
dark_sushi_mix = False
anime = False
icomix = False
flat_2d_animerge = False
arthemy_comics = False
checkpoint_yesmix = False
the_agenda_mix = False
seekyou = False
experience = False
#🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻🔻
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#                                                               ☣️
#   NN   NN        tt                                   !!!     ☣️
#   NNn  NN      TTTTT                  aaAA   RR RRR   !!!     ☣️
#   NNnn NN  ooo   tt      ooo    ooo       A  RRRRR     !      ☣️
#   NN nnnn o   o  tt     o   o  o      aaAA   RRR       !      ☣️
#   NN  nnn o   o  tt tt  o   o  o     A    A  RR               ☣️
#   NN   nn  ooo    ttt    ooo    ooo   AaAA a RR        O      ☣️
#                                                               ☣️
#☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️☣️
#⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬⏬
#🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽🔽
import zipfile
import os
from IPython.display import clear_output
path_model = '/home/studio-lab-user/stable-diffusion-webui/models/Stable-diffusion/'
path_vae = '/home/studio-lab-user/stable-diffusion-webui/models/VAE/'
path_lora = '/home/studio-lab-user/stable-diffusion-webui/models/Lora/'
path_hypernetwork = '/home/studio-lab-user/stable-diffusion-webui/models/hypernetworks/'
path_upscaler = '/home/studio-lab-user/stable-diffusion-webui/models/ESRGAN/'
path_embedding = '/home/studio-lab-user/stable-diffusion-webui/embeddings/'
path_control = '/home/studio-lab-user/stable-diffusion-webui/models/ControlNet/'
def descargarModelo(url,id, total):
	destination = url.split(':')[0]
	nombre = url.split(':')[1]
	url = url[url.find(':')+1:]
	url = url[url.find(':')+1:]
	if 'model' in destination:
		destination = path_model
	elif 'vae' in destination:
		destination = path_vae
	elif 'lora' in destination:
		destination = path_lora
	elif 'hypernetwork' in destination:
		destination = path_hypernetwork
	elif 'embedd' in destination:
		destination = path_embedding
	elif 'control' in destination:
		destination = path_control
	elif 'upscaler' in destination:
		destination = path_upscaler
	if not os.path.exists(destination):
		os.makedirs(destination)
	mostrar_en_div_estilizado(f"Descargando modelos. Puede tardar hasta ~30min. Paso 1/3.")
	mostrar_en_div_estilizado("Descargando " + nombre.split('.')[1] + "(" + str(id+1) + " de " + str(total+1) + ")")
	filename = destination + nombre
	# !curl -Lo $filename $url
	clear_output()
from IPython.utils.io import capture_output
def descargarModelos(modelos):
    for i, model in enumerate(modelos):    
        descargarModelo(model, i, len(modelos))
modelos = []
if sdxl_crystalclear_realista:
	modelos.append('model:sdxl_crystalclear_realista.safetensors:https://civitai.com/api/download/models/133832')
if sdxl_atlxl:
	modelos.append('model:sdxl_atlxl.safetensors:https://civitai.com/api/download/models/144184')
if sdxl_wyvernmix:
	modelos.append('model:sdxl_wyvernmix.safetensors:https://civitai.com/api/download/models/137252')
if sdxl_realxl:
	modelos.append('model:sdxl_realxl.safetensors:https://civitai.com/api/download/models/154590')
if sdxl_juggernaut_realista:
	modelos.append('model:sdxl_juggernaut_realista.safetensors:https://civitai.com/api/download/models/156005')
	# !curl -Lo "/home/studio-lab-user/stable-diffusion-webui/models/Lora/JuggerCineXL2.safetensors" "https://civitai.com/api/download/models/131991"
	# !curl -Lo "/home/studio-lab-user/stable-diffusion-webui/embeddings/JuggernautNegative-neg.pt" "https://civitai.com/api/download/models/86553"
if sdxl_perfectdesign_sxzluma:
	modelos.append('model:sdxl_perfectdesign_sxzluma.safetensors:https://civitai.com/api/download/models/134691')
if sdxl_bluepencil_anime:
	modelos.append('model:sdxl_bluepencil_anime.safetensors:https://civitai.com/api/download/models/147901')
if sdxl_shikianime_anime:
	modelos.append('model:sdxl_shikianime_anime.safetensors:https://civitai.com/api/download/models/129369')
if sdxl_realcartoon:
	modelos.append('model:sdxl_realcartoon.safetensors:https://civitai.com/api/download/models/137588')
if sdxl_ambience:
	modelos.append('model:sdxl_ambience.safetensors:https://civitai.com/api/download/models/129103')
if sdxl_zavy_chroma:
	modelos.append('model:sdxl_zavy_chroma.safetensors:https://civitai.com/api/download/models/142180')
if sdxl_faestatic:
	modelos.append('model:sdxl_faestatic.safetensors:https://civitai.com/api/download/models/142180')
if sdxl_mysterious_ilustracion:
	modelos.append('model:sdxl_mysterious_ilustracion.safetensors:https://civitai.com/api/download/models/144237')
if sdxl_realart_artedigital:
	modelos.append('model:sdxl_realart_artedigital.safetensors:https://civitai.com/api/download/models/140130')
if sdxl_yamer_anime:
	modelos.append('model:sdxl_yamer_anime.safetensors:https://civitai.com/api/download/models/142390')
if sdxl_duchaiten_ilustracion:
	modelos.append('model:sdxl_duchaiten_ilustracion.safetensors:https://civitai.com/api/download/models/136754')
if sdxl_protovision_alicia:
	modelos.append('model:sdxl_protovision_alicia.safetensors:https://civitai.com/api/download/models/144229')
if sdxl_dreamshaper:
	modelos.append('model:sdxl_dreamshaper.safetensors:https://civitai.com/api/download/models/126688')
if sdxl_dynavision_arteDigital:
	modelos.append('model:sdxl_dynavision_arteDigital.safetensors:https://civitai.com/api/download/models/148259')
if sdxl_yamer_ilustracion:
	modelos.append('model:sdxl_yamer_ilustracion.safetensors:https://civitai.com/api/download/models/137744')
if sdxl_copax_realista:
	modelos.append('model:sdxl_copax_realista.safetensors:https://civitai.com/api/download/models/147065')
if sdxl_lora:
    modelos.append('lora:DetailedEyes_V3.safetensors:https://civitai.com/api/download/models/145907')
    modelos.append('lora:xl_more_art-full_v1.safetensors:https://civitai.com/api/download/models/152309')
    modelos.append('lora:add-detail-xl.safetensors:https://civitai.com/api/download/models/135867')
    modelos.append('lora:fashigirl-v6-sdxl-5ep-resize.safetensors:https://civitai.com/api/download/models/129198')
if objective_reality:
    modelos.append('model:objective_reality.safetensors:https://civitai.com/api/download/models/142465')
if chilloutmix:
    modelos.append('model:chilloutmix.safetensors:https://civitai.com/api/download/models/11745')   # chilloutmix
if realistic_vision_v5_1:
    modelos.append('model:realistic_vision_v5_1.safetensors:https://civitai.com/api/download/models/130072')  # realistic_vision_v5_1
if deliberate:
    modelos.append('model:deliberate.safetensors:https://civitai.com/api/download/models/15236')   # deliberate
if majicmix_realistic:
    modelos.append('model:majicmix_realistic.safetensors:https://civitai.com/api/download/models/126470')  # majicmix_realistic
if epic_realism:
    modelos.append('model:epic_realism.safetensors:https://civitai.com/api/download/models/134065')  # epic_realism
if epic_photogasm:
    modelos.append('model:epic_photogasm.safetensors:https://civitai.com/api/download/models/145885')
if cyber_realistic:
    modelos.append('model:cyber_realistic.safetensors:https://civitai.com/api/download/models/138176')  # cyber_realistic
if xxmix_9_realistic:
    modelos.append('model:xxmix_9_realistic.safetensors:https://civitai.com/api/download/models/102222')  # xxmix_9_realistic
if icbinp_i_cant_believe_its_not_photography:
    modelos.append('model:icbinp_i_cant_believe_its_not_photography.safetensors:https://civitai.com/api/download/models/121557')  # icbinp_i_cant_believe_its_not_photography
if fantastic_mix:
    modelos.append('model:fantastic_mix.safetensors:https://civitai.com/api/download/models/129240')  # fantastic_mix
if absolute_reality:
    modelos.append('model:absolute_reality.safetensors:https://civitai.com/api/download/models/132760')  # absolute_reality
if am_i_real:
    modelos.append('model:am_i_real.safetensors:https://civitai.com/api/download/models/115526')  # am_i_real
if experience:
    modelos.append('model:experience.safetensors:https://civitai.com/api/download/models/137204')  # experience
if photon:
    modelos.append('model:photon.safetensors:https://civitai.com/api/download/models/90072')   # photon
if perfect_deliberate:
    modelos.append('model:perfect_deliberate.safetensors:https://civitai.com/api/download/models/86698')   # perfect_deliberate
if cyber_realistic_classic:
    modelos.append('model:cyber_realistic_classic.safetensors:https://civitai.com/api/download/models/129379')  # cyber_realistic_classic
if endless_reality:
    modelos.append('model:endless_reality.safetensors:https://civitai.com/api/download/models/111513')  # endless_reality
if sxz_luma:
    modelos.append('model:sxz_luma.safetensors:https://civitai.com/api/download/models/127416')  # sxz_luma
if dream_shaper:
    modelos.append('model:dream_shaper.safetensors:https://civitai.com/api/download/models/128713')  # dream_shaper
if rev_animated:
    modelos.append('model:rev_animated.safetensors:https://civitai.com/api/download/models/46846')   # rev_animated
if lyriel:
    modelos.append('model:lyriel.safetensors:https://civitai.com/api/download/models/72396')   # lyriel
if babes:
    modelos.append('model:babes.safetensors:https://civitai.com/api/download/models/61372')   # babes
if never_ending_dream_ned:
    modelos.append('model:never_ending_dream_ned.safetensors:https://civitai.com/api/download/models/64094')   # never_ending_dream_ned
if liberty:
    modelos.append('model:liberty.safetensors:https://civitai.com/api/download/models/6908')    # liberty
if elldreths_retro_mix:
    modelos.append('model:elldreths_retro_mix.safetensors:https://civitai.com/api/download/models/1575')    # elldreths_retro_mix
if been_you_lite:
    modelos.append('model:been_you_lite.safetensors:https://civitai.com/api/download/models/117019')  # been_you_lite
if ether_real_mix:
    modelos.append('model:ether_real_mix.safetensors:https://civitai.com/api/download/models/124104')  # ether_real_mix
if dread_v5:
    modelos.append('model:dread_v5.safetensors:https://civitai.com/api/download/models/104018')  # dread_v5
if majicmix_fantasy:
    modelos.append('model:majicmix_fantasy.safetensors:https://civitai.com/api/download/models/49055')   # majicmix_fantasy
if noosphere:
    modelos.append('model:noosphere.safetensors:https://civitai.com/api/download/models/107675')  # noosphere
if model_ex:
    modelos.append('model:model_ex.safetensors:https://civitai.com/api/download/models/137783')  # model_ex
if ghostmix:
    modelos.append('model:ghostmix.safetensors:https://civitai.com/api/download/models/76907')   # ghostmix
if counterfeit_v3_0:
    modelos.append('model:counterfeit_v3_0.safetensors:https://civitai.com/api/download/models/57618')   # counterfeit_v3_0
if a_zovya_rpg_artist_tools:
    modelos.append('model:a_zovya_rpg_artist_tools.safetensors:https://civitai.com/api/download/models/87886')   # a_zovya_rpg_artist_tools
if been_you:
    modelos.append('model:been_you.safetensors:https://civitai.com/api/download/models/85614')   # been_you
if anything_v5_ink:
    modelos.append('model:anything_v5_ink.safetensors:https://civitai.com/api/download/models/90854')   # anything_v5_ink
if cetus_mix:
    modelos.append('model:cetus_mix.safetensors:https://civitai.com/api/download/models/105924')  # cetus_mix
if toonyou:
    modelos.append('model:toonyou.safetensors:https://civitai.com/api/download/models/125771')  # toonyou
if dark_sushi_mix:
    modelos.append('model:dark_sushi_mix.safetensors:https://civitai.com/api/download/models/93208')   # dark_sushi_mix
if anime:
    modelos.append('model:anime.safetensors:https://civitai.com/api/download/models/116978')  # anime
if icomix:
    modelos.append('model:icomix.safetensors:https://civitai.com/api/download/models/84783')   # icomix
if flat_2d_animerge:
    modelos.append('model:flat_2d_animerge.safetensors:https://civitai.com/api/download/models/103436')  # flat_2d_animerge
if arthemy_comics:
    modelos.append('model:arthemy_comics.safetensors:https://civitai.com/api/download/models/107847')  # arthemy_comics
if checkpoint_yesmix:
    modelos.append('model:checkpoint_yesmix.safetensors:https://civitai.com/api/download/models/95214')   # checkpoint_yesmix
if the_agenda_mix:
    modelos.append('model:the_agenda_mix.safetensors:https://civitai.com/api/download/models/95687')   # the_agenda_mix
if seekyou:
    modelos.append('model:seekyou.safetensors:https://civitai.com/api/download/models/74057')   # seekyou
if extra_vae:
    modelos.append('vae:blessed2.vae.safetensors:https://huggingface.co/NoCrypt/resources/resolve/main/VAE/blessed2.vae.safetensors')
    modelos.append('vae:vae-ft-mse-840000-ema-pruned.safetensors:https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors')
    modelos.append('vae:https://civitai.com/api/download/models/94036')
    modelos.append('vae:https://civitai.com/api/download/models/83798')
    modelos.append('vae:https://civitai.com/api/download/models/83141')
else:
    modelos.append('vae:blessed2.vae.safetensors:https://huggingface.co/NoCrypt/resources/resolve/main/VAE/blessed2.vae.safetensors')
    modelos.append('vae:vae-ft-mse-840000-ema-pruned.safetensors:https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors')
modelos.append('upscaler:4xUltrasharp.pt:https://civitai.com/api/download/models/125843')
if sd15_embeddings:
	# %cd /home/studio-lab-user/stable-diffusion-webui/embeddings
	# !git clone --depth 1 https://github.com/dreamscapeai/negativekit
if sd15_controlnet_v1:
    modelos.append('control:depth_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors')
    modelos.append('control:depth_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.yaml')
    modelos.append('control:qrcode_monster_v2.yaml:https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/v2/control_v1p_sd15_qrcode_monster_v2.yaml')
    modelos.append('control:qrcode_monster_v2.safetensors:https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/v2/control_v1p_sd15_qrcode_monster_v2.safetensors')
    modelos.append('control:canny_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors')
    modelos.append('control:canny_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.yaml')
    modelos.append('control:lineart_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors')
    modelos.append('control:lineart_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.yaml')
    modelos.append('control:openpose_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors')
    modelos.append('control:openpose_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.yaml')
    modelos.append('control:scribble_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors')
    modelos.append('control:scribble_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.yaml')
if sd15_controlnet_v2:
    modelos.append('control:ip2p_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors')
    modelos.append('control:ip2p_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.yaml')
    modelos.append('control:shuffle_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors')
    modelos.append('control:shuffle_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.yaml')
    modelos.append('control:tile_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors')
    modelos.append('control:tile_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.yaml')
    modelos.append('control:depth_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_depth_fp16.safetensors')
    modelos.append('control:depth_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_depth_fp16.yaml')
    modelos.append('control:inpaint_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors')
    modelos.append('control:inpaint_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.yaml')
    modelos.append('control:mlsd_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors')
    modelos.append('control:mlsd_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.yaml')
    modelos.append('control:normalbae_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors')
    modelos.append('control:normalbae_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.yaml')
    modelos.append('control:seg_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors')
    modelos.append('control:seg_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.yaml')
    modelos.append('control:softedge_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors')
    modelos.append('control:softedge_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.yaml')
    modelos.append('control:lineart_anime_fp16.safetensors:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors')
    modelos.append('control:lineart_anime_fp16.yaml:https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.yaml')
if sdxl_control:
    modelos.append('sai_xl_canny_256lora.safetensors:https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_canny_256lora.safetensors')
    modelos.append('sai_xl_depth_256lora.safetensors:https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_depth_256lora.safetensors')
    modelos.append('adapter_xl_openpose.safetensors:https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_xl_openpose.safetensors')
from IPython.display import HTML, display
def mostrar_en_div_estilizado(contenido):
    div_style = """
        background-color: #007BFF;
        color: #FFFFFF;
        padding: 15px;
        border-radius: 5px;
        font-weight: bold;
        font-family: Arial, sans-serif;
    """
    div = f'<div class="alert alert-primary" style="{div_style}">{contenido}</div>'
    display(HTML(div))
descargarModelos(modelos)
mostrar_en_div_estilizado(f"Descargando extensiones. Paso 2/3")
with capture_output() as c:
    if sd_extensions:
        # %cd /home/studio-lab-user/stable-diffusion-webui/extensions
        # !git clone --depth 1 https://github.com/zanllp/sd-webui-infinite-image-browsing
        # !git clone --depth 1 https://github.com/dreamscapeai/CN-v11400
        # !git clone --depth 1 https://github.com/dreamscapeai/adetailer
        # !git clone --depth 1 https://github.com/dreamscapeai/ultimatesdupscale
        # !git clone --depth 1 https://github.com/dreamscapeai/tagcomplete
        # !git clone --depth 1 https://github.com/thomasasfk/sd-webui-aspect-ratio-helper
        # !git clone --depth 1 https://github.com/uwidev/sd_extension-prompt_formatter
        # !git clone --depth 1 https://github.com/deforum-art/sd-webui-deforum
    del c
clear_output()
mostrar_en_div_estilizado(f"Descargando embeddings. Paso 3/3")
with capture_output() as c:
    if sdxl_embeddings:
        # %cd /home/studio-lab-user/stable-diffusion-webui/embeddings
        # !git clone --depth 1 https://github.com/ositoMalvado/sdxl_embeddings
    del c
clear_output()
mostrar_en_div_estilizado(f"Modelos y extensiones descargados! Ya puedes iniciar Stable Diffusion en la siguiente celda!")

# %% [markdown]
# # 🚀 Iniciar Stable Diffusion 🛸
# Celda 3 de 3
# - Importante:
# > [Debes usar tu propio token de ngrok](https://dashboard.ngrok.com/get-started/your-authtoken). Iniciando la sesión en esta página podrás obtener tu token. Colócalo en la celda de abajo.
# >
# Ejemplo:
# ```
# ngrok_token = "TU_TOKEN_AQUÍ"
# ```

# %%
ngrok_token = "TU_TOKEN_AQUÍ"

#INICIAR STABLE DIFFUSION CON ESTA CELDA
from IPython.display import HTML, display
div_style = """
    background-color: #007BFF;
    color: #FFFFFF;
    padding: 2px;
    border-radius: 5px;
    font-weight: bold;
    font-family: Arial, sans-serif;
"""
div = f'<img src="https://lithi.io/file/6f0l.png" style="{div_style}"/>'
display(HTML(div))
# %cd /home/studio-lab-user/stable-diffusion-webui
# !python launch.py --listen --xformers --enable-insecure-extension-access --no-half-vae --theme dark --gradio-queue --ngrok $ngrok_token
